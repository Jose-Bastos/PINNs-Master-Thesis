# %% [markdown]
# # Noise plots

# %% [markdown]
# Notebook to generate plots for the results of the effect of Noise in the determined coefficients error.

# %%
import numpy as np
import matplotlib.pyplot as plt
plt.rcParams.update({'font.size': 22})
import os
os.chdir("/notebooks")
# %load_ext autoreload
# %autoreload 2

# %%
noise_levels = [0,1,5,10,25,50]

# %%
error0  = np.array([2.0,2.2,1.9,1.93,1.9])
error1 = np.array([2.16,3.04,2.48,3.42,2.43,3.37,2.11,3.32])
error5 = np.array([	1.88,3.6,2.98,3.1,1.17,1.84])
error10 = np.array([4.96,8.53,5.32,9.89,5.13,8.35,2.63,5.07])
error25 = np.array([63.78,81.93,12.24,17.15,14.55,21.84,16.50,26.1,15.51,23.92])
error50 =np.array([51.30,74.05,51.98,80.40,74.65,84.80])

# %%
mean0 = np.mean(error0)
mean1 = np.mean(error1)
mean5 = np.mean(error5)
mean10 = np.mean(error10)
mean25 = np.mean(error25)
mean50 = np.mean(error50)

std0 = np.std(error0)
std1 = np.std(error1)
std5 = np.std(error5)
std10 = np.std(error10)
std25 = np.std(error25)
std50= np.std(error50)

means = [mean0,mean1,mean5,mean10,mean25,mean50]
stds = [std0,std1,std5,std10,std25,std50]

for i,noise in enumerate(noise_levels):
    print("Noise level is:",noise)
    print("mean is:",means[i])
    print("std is:",stds[i])
    print()
# Out:
# Noise level is: 0
# mean is: 1.986
# std is: 0.11306635220082066
#
# Noise level is: 1
# mean is: 2.7912500000000002
# std is: 0.5198181773466565
#
# Noise level is: 5
# mean is: 2.4283333333333332
# std is: 0.8522991780407212
#
# Noise level is: 10
# mean is: 6.234999999999999
# std is: 2.267608872799716
#
# Noise level is: 25
# mean is: 29.352000000000004
# std is: 22.502953050655375
#
# Noise level is: 50
# mean is: 69.53
# std is: 13.154910363307943

# %%
plt.figure(figsize=(20,10))
#xmarkers = 
plt.grid()
plt.xlabel("Noise level(m)")
plt.ylabel("Percentage of error in determined coefficients(%)")
plt.plot(noise_levels,means,'--o',label="Error in coeficients",markersize=10)
plt.errorbar(noise_levels,means,yerr=stds,fmt='none')
plt.legend()
plt.savefig("noise.png",format="png",bbox_inches="tight")
plt.show()

# %%
plt.figure(figsize=(20,10))
#xmarkers = 
plt.grid()
plt.xlabel("Noise level(%)")
plt.ylabel("Percentage of error in determined coefficients(%)")
plt.hlines(3,0,10,label="y=3%",color="red",linestyle="--")
plt.xticks(np.arange(0,11,1))
plt.plot(noise_levels[:-2],means[:-2],'--o',label="Error in coeficients",markersize=10)
plt.errorbar(noise_levels[:-2],means[:-2],yerr=stds[:-2],fmt='none')
plt.legend()
plt.savefig("noise_zoom.png",format="png",bbox_inches="tight")
plt.show()

# %%
val_loss = [0.00032,0.0004,0.0008,0.0025,0.1,1.4]
errors    = [0.0002,0.0002,0.0002,0.0009,0.2,0.5]
plt.figure(figsize=(20,10))
xmarkers = [0,1,5]
xmarkers = np.append(xmarkers,np.arange(0,11,1))
plt.xticks(xmarkers)
plt.grid()
plt.xlabel("Noise level(%)")
plt.ylabel("Validation Loss")
plt.plot(noise_levels[:-2],val_loss[:-2],'--o',label="Error in coeficients",markersize=10)
plt.errorbar(noise_levels[:-2],val_loss[:-2],yerr=errors[:-2],fmt='none')
plt.savefig("forward_noise_zoom.png",format="png",bbox_inches="tight")
plt.legend()
plt.show()

# %%
val_loss = [0.00032,0.0004,0.0008,0.0025,0.1,1.4]
errors    = [0.0002,0.0002,0.0002,0.0009,0.2,0.5]
plt.figure(figsize=(20,10))

xmarkers = np.array([0,1,5,10,25,50])
xmarkers  = np.append(xmarkers,np.arange(0,60,10))
plt.xticks(xmarkers)
plt.grid()
plt.xlabel("Noise level(%)")
plt.ylabel("Validation Loss")
plt.plot(noise_levels,val_loss,'--o',label="Error in coeficients",markersize=10)
plt.errorbar(noise_levels,val_loss,yerr=errors,fmt='none')
plt.savefig("forward_noise.png",format="png",bbox_inches="tight")
plt.legend()
plt.show()

# %%
for i in range(len(noise_levels)):
    print()
    print(noise_levels[i])
    print(val_loss[i])
    print(errors[i])
# Out:
# 0
# 0.00032
# 0.0002
#
# 1
# 0.0004
# 0.0002
#
# 5
# 0.0008
# 0.0002
#
# 10
# 0.0025
# 0.0009
#
# 25
# 0.1
# 0.2
#
# 50
# 1.4
# 0.5
